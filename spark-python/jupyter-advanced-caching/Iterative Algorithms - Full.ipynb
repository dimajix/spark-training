# %%
import pyspark.sql
import pyspark.sql.functions as sf

# %%
spark = pyspark.sql.SparkSession.Builder().getOrCreate()

# %% [markdown]
# # 1 Fictional Sales Data
#
# In this example we use a fictional data set of company revenues. The special property of this data set is that a company can have a different company as its parent company. Eventually a business expert wants to see the whole revenue of a company including all child companies. This requires that we build up an additional table containing all children (direct and indirect) for every company, such that we can join the revenues against this table and then aggregate over all direct and indirect children for each parent.

# %% [markdown]
# Let's start by loading and inspecting the data.

# %%
basedir = "s3://dimajix-training/data"

# %%
data = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .csv(basedir + "/global-sales.csv")

data.printSchema()
# Out:
# root
#  |-- company: integer (nullable = true)
#  |-- parent_company: integer (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- revenue: integer (nullable = true)

# %%
data.toPandas()
# Out:
#     company  parent_company            company_name  revenue
# 0         1             NaN        Global Earth Inc    10000
# 1         2             1.0        European Markets        0
# 2         3             2.0      Germany Sales GmbH     2000
# 3         4             2.0          Spain Products   123000
# 4         5             2.0              Swiss Made   213000
# 5         6             2.0       France Superstars   241000
# 6         7             3.0            Berlin Store   287000
# 7         8             3.0           Hamburg Store   312000
# 8         9             3.0     Hessian Store Group    10000
# 9        10             9.0  Frankfurt Shop Central   287000
# 10       11             9.0     Frankfurt Shop East   121000
# 11       12             9.0          Darmstadt Shop    90000
# 12       13             1.0        American Markets   100000
# 13       14             1.0           Asian Markets   100000
# 14       15             1.0         African Markets   100000
# 15       16            13.0               USA Group  2131000
# 16       17            15.0          Egypt Products    97000
# 17       18            14.0               China Inc  2891000
# 18       19            14.0         Japanese Stores  2179820
# 19       20            14.0           Korean United   198000

# %% [markdown]
# # 2 Single Step of transitive parent-child relations
#
# In the next step we want to build the helper table containing all children for every company. We will calculate this table using an iterative algorithm which adds the next level of children in every iteration. We first implement a single iteration, which will add the next level of children to each parent company.

# %%
# Remove all records without a parent company for the algorithm
cleaned_df = data \
    .filter(data["parent_company"].isNotNull()) \
    .select(data["company"], data["parent_company"])

# %%
def iterate_parent_child(df):
    # Denote the incoming table "parent" and "child", since we will do a self-join and the join condition would be ambigious without aliases otherwise
    parent_df = df.alias("parent")
    child_df = df.alias("child")
    
    # Calculate next levels of indirect children by joining the table to itself and by retrieving the child of each child of each parent
    next_level = parent_df.join(child_df, sf.col("parent.company") == sf.col("child.parent_company"), "inner") \
        .select(sf.col("parent.parent_company"), sf.col("child.company"))

    # Add current relations, otherwise they will be lost
    cur_level = parent_df.select(parent_df["parent_company"], parent_df["company"])
    
    # Return union of next indirection and current relations
    return next_level.union(cur_level).distinct()

# %% [markdown]
# ### Perform one iteration
#
# Now let us perform a single iteration and inspect the result.

# %%
next = iterate_parent_child(cleaned_df)
next.orderBy("parent_company","company").toPandas()
# Out:
#     parent_company  company
# 0                1        2
# 1                1        3
# 2                1        4
# 3                1        5
# 4                1        6
# 5                1       13
# 6                1       14
# 7                1       15
# 8                1       16
# 9                1       17
# 10               1       18
# 11               1       19
# 12               1       20
# 13               2        3
# 14               2        4
# 15               2        5
# 16               2        6
# 17               2        7
# 18               2        8
# 19               2        9
# 20               3        7
# 21               3        8
# 22               3        9
# 23               3       10
# 24               3       11
# 25               3       12
# 26               9       10
# 27               9       11
# 28               9       12
# 29              13       16
# 30              14       18
# 31              14       19
# 32              14       20
# 33              15       17

# %% [markdown]
# # 3 Iterative Algorithm
#
# Now that we can add one level of indirection to our table of parent-child relations, we simply need to apply this algorithm as often as new records are created. We also add a reflective relation of each company to itself at the end, such that when using the table for aggregating all children, the revenue of each company itself  will also be added up in addition to its children.

# %%
def calc_transitive_children(df):
    # Remove records without a parent
    cleaned_df = data \
        .filter(data["parent_company"].isNotNull()) \
        .select(data["company"], data["parent_company"])
    
    # Iterate as long as new records are created
    cur_df = cleaned_df
    cur_count = cur_df.count()

    while (True):
        next_df = iterate_parent_child(cur_df)
        next_count = next_df.count()
        # If no new records are created, we are finished
        if next_count == cur_count:
            break
        # This would be a good place to perform a checkpoint
        cur_df = next_df        
        cur_count = next_count
        
    # Create additional reflective relation of each company to irself
    self_df = data.select(sf.col("company").alias("parent_company"), sf.col("company"))
    
    return self_df.union(cur_df).distinct()

# %% [markdown]
# ### Run Algorithm
#
# Now let us run the whole algorithm on the original data set and inspect the result.

# %%
relations = calc_transitive_children(data)

relations.orderBy("parent_company","company").toPandas()
# Out:
#     parent_company  company
# 0                1        1
# 1                1        2
# 2                1        3
# 3                1        4
# 4                1        5
# 5                1        6
# 6                1        7
# 7                1        8
# 8                1        9
# 9                1       10
# 10               1       11
# 11               1       12
# 12               1       13
# 13               1       14
# 14               1       15
# 15               1       16
# 16               1       17
# 17               1       18
# 18               1       19
# 19               1       20
# 20               2        2
# 21               2        3
# 22               2        4
# 23               2        5
# 24               2        6
# 25               2        7
# 26               2        8
# 27               2        9
# 28               2       10
# 29               2       11
# ..             ...      ...
# 33               3        8
# 34               3        9
# 35               3       10
# 36               3       11
# 37               3       12
# 38               4        4
# 39               5        5
# 40               6        6
# 41               7        7
# 42               8        8
# 43               9        9
# 44               9       10
# 45               9       11
# 46               9       12
# 47              10       10
# 48              11       11
# 49              12       12
# 50              13       13
# 51              13       16
# 52              14       14
# 53              14       18
# 54              14       19
# 55              14       20
# 56              15       15
# 57              15       17
# 58              16       16
# 59              17       17
# 60              18       18
# 61              19       19
# 62              20       20
#
# [63 rows x 2 columns]

# %% [markdown]
# ### Inspect execution plan

# %%
relations.explain()
# Out:
# == Physical Plan ==
# *(20) HashAggregate(keys=[parent_company#1319, company#28], functions=[])
# +- Exchange hashpartitioning(parent_company#1319, company#28, 200)
#    +- *(19) HashAggregate(keys=[parent_company#1319, company#28], functions=[])
#       +- Union
#          :- *(1) Project [company#28 AS parent_company#1319, company#28]
#          :  +- *(1) FileScan csv [company#28] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<company:int>
#          +- *(18) HashAggregate(keys=[parent_company#29, company#1217], functions=[])
#             +- Exchange hashpartitioning(parent_company#29, company#1217, 200)
#                +- *(17) HashAggregate(keys=[parent_company#29, company#1217], functions=[])
#                   +- Union
#                      :- *(11) Project [parent_company#29, company#1217]
#                      :  +- *(11) BroadcastHashJoin [company#1170], [parent_company#1206], Inner, BuildRight
#                      :     :- *(11) HashAggregate(keys=[parent_company#29, company#1170], functions=[])
#                      :     :  +- Exchange hashpartitioning(parent_company#29, company#1170, 200)
#                      :     :     +- *(5) HashAggregate(keys=[parent_company#29, company#1170], functions=[])
#                      :     :        +- Union
#                      :     :           :- *(3) Project [parent_company#29, company#1170]
#                      :     :           :  +- *(3) BroadcastHashJoin [company#28], [parent_company#1171], Inner, BuildRight
#                      :     :           :     :- *(3) Project [company#28, parent_company#29]
#                      :     :           :     :  +- *(3) Filter (isnotnull(parent_company#29) && isnotnull(company#28))
#                      :     :           :     :     +- *(3) FileScan csv [company#28,parent_company#29] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company), IsNotNull(company)], ReadSchema: struct<company:int,parent_company:int>
#                      :     :           :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[1, int, true] as bigint)))
#                      :     :           :        +- *(2) Project [company#1170, parent_company#1171]
#                      :     :           :           +- *(2) Filter (isnotnull(parent_company#1171) && isnotnull(company#1170))
#                      :     :           :              +- *(2) FileScan csv [company#1170,parent_company#1171] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company), IsNotNull(company)], ReadSchema: struct<company:int,parent_company:int>
#                      :     :           +- *(4) Project [parent_company#29, company#28]
#                      :     :              +- *(4) Filter (isnotnull(parent_company#29) && isnotnull(company#28))
#                      :     :                 +- *(4) FileScan csv [company#28,parent_company#29] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company), IsNotNull(company)], ReadSchema: struct<company:int,parent_company:int>
#                      :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint)))
#                      :        +- *(10) HashAggregate(keys=[parent_company#1206, company#1217], functions=[])
#                      :           +- Exchange hashpartitioning(parent_company#1206, company#1217, 200)
#                      :              +- *(9) HashAggregate(keys=[parent_company#1206, company#1217], functions=[])
#                      :                 +- Union
#                      :                    :- *(7) Project [parent_company#1206, company#1217]
#                      :                    :  +- *(7) BroadcastHashJoin [company#1205], [parent_company#1218], Inner, BuildRight
#                      :                    :     :- *(7) Project [company#1205, parent_company#1206]
#                      :                    :     :  +- *(7) Filter (isnotnull(parent_company#1206) && isnotnull(company#1205))
#                      :                    :     :     +- *(7) FileScan csv [company#1205,parent_company#1206] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company), IsNotNull(company)], ReadSchema: struct<company:int,parent_company:int>
#                      :                    :     +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[1, int, true] as bigint)))
#                      :                    :        +- *(6) Project [company#1217, parent_company#1218]
#                      :                    :           +- *(6) Filter isnotnull(parent_company#1218)
#                      :                    :              +- *(6) FileScan csv [company#1217,parent_company#1218] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company)], ReadSchema: struct<company:int,parent_company:int>
#                      :                    +- *(8) Project [parent_company#1206, company#1205]
#                      :                       +- *(8) Filter isnotnull(parent_company#1206)
#                      :                          +- *(8) FileScan csv [company#1205,parent_company#1206] Batched: false, Format: CSV, Location: InMemoryFileIndex[file:/home/kaya/Trainings/spark-training/data/global-sales.csv], PartitionFilters: [], PushedFilters: [IsNotNull(parent_company)], ReadSchema: struct<company:int,parent_company:int>
#                      +- *(16) HashAggregate(keys=[parent_company#29, company#1170], functions=[])
#                         +- ReusedExchange [parent_company#29, company#1170], Exchange hashpartitioning(parent_company#1206, company#1217, 200)

# %% [markdown]
# # 4 Perform Aggregation
#
# Now let us perform the final aggregation, such that we can calculate the revenue of each company including each direct and indirect child. This can be performed by joining the `relations` data frame to the original `data` data frame and then grouping on the `parent_company` column of the `relations` data frame and adding up the revenue.

# %%
hierarchical_revenue = relations \
    .join(data, ["company"]) \
    .groupby(relations["parent_company"]) \
    .agg(sf.sum(sf.col("revenue")).alias("total_revenue"))

# %%
hierarchical_revenue.toPandas()
# Out:
#     parent_company  total_revenue
# 0               12          90000
# 1                1        9492820
# 2               13        2231000
# 3               16        2131000
# 4                6         241000
# 5                3        1109000
# 6               20         198000
# 7                5         213000
# 8               19        2179820
# 9               15         197000
# 10               9         508000
# 11              17          97000
# 12               4         123000
# 13               8         312000
# 14               7         287000
# 15              10         287000
# 16              11         121000
# 17              14        5368820
# 18               2        1686000
# 19              18        2891000

# %% [markdown]
# ### Check Totals
#
# Just to verify the result, let us compare the result of company 1 ("Earth") with a simple sum over all revenues.

# %%
totals = data.select(sf.sum(data["revenue"]))
totals.toPandas()
# Out:
#    sum(revenue)
# 0       9492820
