# %% [markdown]
# # Strings and Printing

# %%
hello = "Hello"
world = "World!"

print(hello + " " + world)
# Out:
# Hello World!

# %%
print("%s %s" % (hello,world))
# Out:
# Hello World!

# %%
print("{0} {1}".format(hello,world))
# Out:
# Hello World!

# %%
s = hello + " " + world
s
# Out:
# 'Hello World!'

# %%
s[2:8]
# Out:
# 'llo Wo'

# %% [markdown]
# # Numeric Values

# %%
n = 10
m = 10 / 3

print("m=" + str(m))
# Out:
# m=3.3333333333333335

# %% [markdown]
# # Arrays and Loops

# %%
names = ["Alice","Bob","Charlie"]

for n in names:
    print(n)
# Out:
# Alice
# Bob
# Charlie

# %%
print(names[1])
# Out:
# Bob

# %%
print(names[0:2])
# Out:
# ['Alice', 'Bob']

# %% [markdown]
# # Sets and Dictionaries

# %%
names = {"Alice", "Bob", "Alice"}

for n in names:
    print(n)
# Out:
# Bob
# Alice

# %%
names_ages = {"Alice":23, "Bob":27, "Charlie":33}

for na in names_ages.items():
    print(na)
# Out:
# ('Charlie', 33)
# ('Bob', 27)
# ('Alice', 23)

# %%
print("Alice is %d years old" % names_ages["Alice"])
# Out:
# Alice is 23 years old

# %% [markdown]
# # Functions

# %%
def print_age(name):
    print("%s is %d years old" %(name, names_ages[name]))
    
print_age("Alice")
# Out:
# Alice is 23 years old

# %%
print_age("Eve")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-88cdcb564d45> in <module>()
# ----> 1 print_age("Eve")
#
# <ipython-input-19-fe9288e072eb> in print_age(name)
#       1 def print_age(name):
# ----> 2     print("%s is %d years old" %(name, names_ages[name]))
#       3
#       4 print_age("Alice")
#
# KeyError: 'Eve'

# %% [markdown]
# # Conditions

# %%
def print_age(name):
    if name in names_ages:
        print("%s is %d years old" %(name, names_ages[name]))
    else:
        print("%s is not known" % name)
        
print_age("Bob")
print_age("Eve")
# Out:
# Bob is 27 years old
# Eve is not known
